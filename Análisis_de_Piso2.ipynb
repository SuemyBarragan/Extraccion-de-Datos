# %%
# Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carga desde un archivo .excel sin indice
data = pd.read_excel('Análisis de piso 2.xlsx', index_col=False)
data.head(5)
# Out:
#   Ventas Piso 2024 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                9          5          9          1          3         10
# 1              feb        mar        abr        may        jun        jul
# 2                         NaN        NaN        NaN        NaN        NaN
# 3                         NaN        NaN        NaN        NaN        NaN
# 4                         NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...    Unnamed: 21  \
# 0          9          6          3         11  ...  RAKING VENTAS
# 1        ago        sep        oct        nov  ...            NaN
# 2        NaN        NaN        NaN        NaN  ...             23
# 3        NaN        NaN        NaN          1  ...              6
# 4        NaN        NaN        NaN        NaN  ...              0
#
#             Unnamed: 22               979               811     Unnamed: 25  \
# ...

# %%
# Identificar valores nulos por columna
valores_nulos=data.isnull().sum()

# %%
# Identificar valores nulos por columna
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Ventas Piso 2024                          0
# Unnamed: 1                               38
# Unnamed: 2                               35
# Unnamed: 3                               39
# Unnamed: 4                               38
# Unnamed: 5                               36
# Unnamed: 6                               36
# Unnamed: 7                               35
# Unnamed: 8                               38
# Unnamed: 9                               34
# Unnamed: 10                              34
# Unnamed: 11                              35
# Ventas Piso 2025                         33
# Unnamed: 13                              35
# Unnamed: 14                               0
# Unnamed: 15                              34
# * se actualiza al reportar en Sale-U     38
# Unnamed: 17                               1
# Unnamed: 18                               1
# Unnamed: 19                               1
# 263                                      15
# ...

# %%
# Cambiamos todos los valores nulos por 0
data = data.fillna(0)

# %%
# Corroborar datos nulos 
# Identificar valores nulos por columna
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Ventas Piso 2024                         0
# Unnamed: 1                               0
# Unnamed: 2                               0
# Unnamed: 3                               0
# Unnamed: 4                               0
# Unnamed: 5                               0
# Unnamed: 6                               0
# Unnamed: 7                               0
# Unnamed: 8                               0
# Unnamed: 9                               0
# Unnamed: 10                              0
# Unnamed: 11                              0
# Ventas Piso 2025                         0
# Unnamed: 13                              0
# Unnamed: 14                              0
# Unnamed: 15                              0
# * se actualiza al reportar en Sale-U     0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# 263                                      0
# Unnamed: 21                              0
# ...

# %%
#Convertir DataFrame a CSV
data.to_csv("Análisis_de_Piso2_Sin_Nulos.csv", index=False)
