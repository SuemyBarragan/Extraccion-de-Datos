# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
df = pd.read_excel('Ventas_por_Asesor.xlsx')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ventas X Mes   53 non-null     str
#  1   12             33 non-null     object
#  2   7              32 non-null     object
#  3   8              32 non-null     object
#  4   13             32 non-null     object
#  5   6              32 non-null     object
#  6   21             32 non-null     object
#  7   17             32 non-null     object
#  8   17.1           32 non-null     object
#  9   23             32 non-null     object
#  10  22             32 non-null     object
#  11  32             32 non-null     object
#  12  26             33 non-null     object
#  13  20             32 non-null     object
#  14  30             31 non-null     object
#  15  30.1           34 non-null     object
#  16  34             32 non-null     object
#  17  40             15 non-null     object
# ...

# %%
df
# Out:
#                  Ventas X Mes                    12                    7  \
# 0                          NaN  2024-02-01 00:00:00  2024-03-01 00:00:00
# 1              Nombre vendedor                 2024                  NaN
# 2     PEDRO GONZALEZ ESPINDOLA
# 3   VICTOR MANUEL SANCHEZ ARRO
# 4     MIGUEL ANGEL SONDEREGGER
# 5    JOSE ANTONIO LICONA MENDE                    1
# 6        JAIME GONZALEZ CORONA                                         2
# 7    ALAN GONZÁLEZ BELANZATEGU
# 8   MAURICIO ALFREDO VAZQUEZ F
# 9    AURELIO FELIPE TORRES REV
# 10  J4OSETTE RAMON NAVA FLORES
# 11   CARLOS ALBERTO NIETO MERI
# 12    NANCY OLASCOAGA CASTILLO
# 13       DANIEL DE LEON CANDIA
# 14    DANIELA DURAN BERNARDINO                    5                    2
# 15   GUADALUPE PALACIOS HERNÁN
# 16         CARLOS CORTES TEXIS
# 17         RICARDO SILVA HERAS                  NaN                  NaN
# 18         PAUL ROSAS YRIGOYEN                                         1
# ...

# %%
#Eliminar primera fila o filas innecesarias
df1= pd.read_excel('Ventas_por_Asesor.xlsx', skiprows=1)
df1
# Out:
#                     Unnamed: 0 2024-02-01 00:00:00 2024-03-01 00:00:00  \
# 0              Nombre vendedor                2024                 NaN
# 1     PEDRO GONZALEZ ESPINDOLA
# 2   VICTOR MANUEL SANCHEZ ARRO
# 3     MIGUEL ANGEL SONDEREGGER
# 4    JOSE ANTONIO LICONA MENDE                   1
# 5        JAIME GONZALEZ CORONA                                       2
# 6    ALAN GONZÁLEZ BELANZATEGU
# 7   MAURICIO ALFREDO VAZQUEZ F
# 8    AURELIO FELIPE TORRES REV
# 9   J4OSETTE RAMON NAVA FLORES
# 10   CARLOS ALBERTO NIETO MERI
# 11    NANCY OLASCOAGA CASTILLO
# 12       DANIEL DE LEON CANDIA
# 13    DANIELA DURAN BERNARDINO                   5                   2
# 14   GUADALUPE PALACIOS HERNÁN
# 15         CARLOS CORTES TEXIS
# 16         RICARDO SILVA HERAS                 NaN                 NaN
# 17         PAUL ROSAS YRIGOYEN                                       1
# 18   OSCAR ALONSO VELÁZQUEZ HE
# 19    JOSE MANUEL LOPEZ AGUILA                   3
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0              0
# 2024-02-01 00:00:00    21
# 2024-03-01 00:00:00    22
# 2024-04-01 00:00:00    22
# 2024-05-01 00:00:00    22
# 2024-06-01 00:00:00    22
# 2024-07-01 00:00:00    22
# 2024-08-01 00:00:00    22
# 2024-09-01 00:00:00    22
# 2024-10-01 00:00:00    22
# 2024-11-01 00:00:00    22
# 2024-12-01 00:00:00    22
# 2025-01-01 00:00:00    21
# 2025-02-01 00:00:00    22
# 2025-03-01 00:00:00    23
# 2025-04-01 00:00:00    20
# 2025-05-01 00:00:00    22
# 2025-06-01 00:00:00    39
# 2025-07-01 00:00:00    40
# 2025-08-01 00:00:00    41
# 2025-09-01 00:00:00    38
# 2025-10-01 00:00:00    38
# 2025-11-01 00:00:00    40
# 2025-12-01 00:00:00    39
# 2026-01-01 00:00:00    40
# 2026-02-01 00:00:00    38
# 2026-03-01 00:00:00    38
# 2026-04-01 00:00:00    38
# 2026-05-01 00:00:00    41
# 2026-06-01 00:00:00    39
# 2026-07-01 00:00:00    45
# Unnamed: 31             1
# Unnamed: 32             3
# 2024                    0
# Unnamed: 34             3
# ...

# %%
#Identificar valores nulos por dataframe
valores_nulos=df1.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(915)

# %%
#Realizamos una copia del dataframe
df2=df1.copy()

# %%
# 1. Convertir los nombres de todas las columnas a texto
df2.columns = df2.columns.astype(str)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-02-01 00:00:00'] = df2['2024-02-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-03-01 00:00:00'] = df2['2024-03-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-04-01 00:00:00'] = df2['2024-04-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-05-01 00:00:00'] = df2['2024-05-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-06-01 00:00:00'] = df2['2024-06-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-07-01 00:00:00'] = df2['2024-07-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-08-01 00:00:00'] = df2['2024-08-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-09-01 00:00:00'] = df2['2024-09-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-10-01 00:00:00'] = df2['2024-10-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-11-01 00:00:00'] = df2['2024-11-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2024-12-01 00:00:00'] = df2['2024-12-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-01-01 00:00:00'] = df2['2025-01-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-02-01 00:00:00'] = df2['2025-02-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-03-01 00:00:00'] = df2['2025-03-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-04-01 00:00:00'] = df2['2025-04-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-05-01 00:00:00'] = df2['2025-01-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-06-01 00:00:00'] = df2['2025-06-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-07-01 00:00:00'] = df2['2025-07-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-08-01 00:00:00'] = df2['2025-08-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-09-01 00:00:00'] = df2['2025-09-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-10-01 00:00:00'] = df2['2025-10-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-11-01 00:00:00'] = df2['2025-11-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2025-12-01 00:00:00'] = df2['2025-12-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-01-01 00:00:00'] = df2['2026-01-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-02-01 00:00:00'] = df2['2026-02-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-03-01 00:00:00'] = df2['2026-03-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-04-01 00:00:00'] = df2['2026-04-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-05-01 00:00:00'] = df2['2026-05-01 00:00:00'].fillna(0)

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df2['2026-06-01 00:00:00'] = df2['2026-06-01 00:00:00'].fillna(0)

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2['2026-07-01 00:00:00'] = df2['2026-07-01 00:00:00'].fillna(0)

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2["Unnamed: 31"] =df2["Unnamed: 31"].fillna("-")

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2["Unnamed: 32"] =df2["Unnamed: 32"].fillna("-")

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2["Unnamed: 34"] =df2["Unnamed: 34"].fillna("-")

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2["Unnamed: 36"] =df2["Unnamed: 36"].fillna("-")

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df2["Unnamed: 38"] =df2["Unnamed: 38"].fillna("-")

# %%
#Corroboramos valores nulos
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0             0
# 2024-02-01 00:00:00    0
# 2024-03-01 00:00:00    0
# 2024-04-01 00:00:00    0
# 2024-05-01 00:00:00    0
# 2024-06-01 00:00:00    0
# 2024-07-01 00:00:00    0
# 2024-08-01 00:00:00    0
# 2024-09-01 00:00:00    0
# 2024-10-01 00:00:00    0
# 2024-11-01 00:00:00    0
# 2024-12-01 00:00:00    0
# 2025-01-01 00:00:00    0
# 2025-02-01 00:00:00    0
# 2025-03-01 00:00:00    0
# 2025-04-01 00:00:00    0
# 2025-05-01 00:00:00    0
# 2025-06-01 00:00:00    0
# 2025-07-01 00:00:00    0
# 2025-08-01 00:00:00    0
# 2025-09-01 00:00:00    0
# 2025-10-01 00:00:00    0
# 2025-11-01 00:00:00    0
# 2025-12-01 00:00:00    0
# 2026-01-01 00:00:00    0
# 2026-02-01 00:00:00    0
# 2026-03-01 00:00:00    0
# 2026-04-01 00:00:00    0
# 2026-05-01 00:00:00    0
# 2026-06-01 00:00:00    0
# 2026-07-01 00:00:00    0
# Unnamed: 31            0
# Unnamed: 32            0
# 2024                   0
# Unnamed: 34            0
# 2025                   0
# Unnamed: 36            0
# ...

# %%
#Corroboramos valores nulos en todo el dataframe
valores_nulos=df2.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %%
#Convertir DataFrame a CSV
df2.to_csv("Ventas_por_Asesor_sin_nulos.csv")
